# %%
import os
import string
import sys

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.decomposition import PCA

# %%
sys.path.append("../../src/.")
import plotting_functions as pf

# %%
DIR = "../../data/"
SUBWAYUS = "Subway USA/subway_usa_"

# %%
train_df = pd.read_csv(DIR + SUBWAYUS + "processed_train.csv", index_col="store")
test_df = pd.read_csv(DIR + SUBWAYUS + "processed_test.csv", index_col="store")

# %%
result_df = pd.DataFrame([], index=train_df.index)

# %% [markdown]
# ## PCA

# %% [markdown]
# ### Test for Mininum Components to Capture 90% Variance

# %%
pf.pca_plot(train_df)
# Out:
# 35

# %% [markdown]
# ### PCA model (90% Variance) - Layer 1

# %%
pca_1 = PCA(n_components=35, whiten=True, random_state=42)
pca_1.fit(train_df)
# Out:
# PCA(n_components=35, random_state=42, whiten=True)

# %% [markdown]
# #### Filter and Count Important Features (of heavy weights)
#
# Filter the values in the PCA component matrix, and count the occurrence of the features in the filtered matrix.

# %%
W = abs(pca_1.components_)
features = train_df.columns
long_results = []
for i in range(W.shape[0]):
    array = W[i]
    heavy_idx = np.where(array > 0.2)
    long_results += list(features[heavy_idx])

# %%
count = pd.Series(long_results).value_counts()
pca_features = count.index.tolist()
len(count)
# Out:
# 66

# %%
weighted_W = pca_1.explained_variance_ratio_ * W.T
pca_feature_weight = pd.Series(np.sum(weighted_W, axis=1), index=train_df.columns.tolist())
pca_feature_weight = pca_feature_weight.filter(items=pca_features, axis=0)
pca_feature_weight.sort_values(ascending=False, inplace=True)
pca_feature_weight
# Out:
# market_size                   0.151985
# store_density                 0.076925
# emp_p_ta                      0.068560
# centerxy_gla_effective_5mi    0.068337
# genx_p_ta                     0.067440
#                                 ...
# occ_bc_p_ta                   0.051100
# hhinc30lt_p_ta                0.050295
# popgr10cn_ta                  0.049126
# wealth_hhavg_ta               0.047430
# other_p_ta                    0.039875
# Length: 66, dtype: float64

# %%
important_features = pca_feature_weight[:60].index.tolist()

# %%
reduced_train = train_df[pca_features]
reduced_test = test_df[pca_features]
reduced_train
# Out:
#          market_size  popgr10cn_ta  other_p_ta
# store
# 6150300          2.0     -0.248036   -0.352255  \
# 3784100          2.0      0.285237    0.213035
# 1192500          2.0     -0.241841    0.068600
# 449400           4.0     -0.117522   -0.399570
# 2292700          0.0     -0.187331   -0.250154
# ...              ...           ...         ...
# 2440100          4.0     -0.299179   -0.334823
# 6487000          4.0      0.038132   -0.299959
# 2493300          1.0     -0.235070   -0.302450
# 1160000          4.0     -0.136204   -0.695912
# 3070300          0.0     -0.223798   -0.417002
#
#          nces_public_schools_nearest_dist  osm_highway_exits_count_1mi
# store
# 6150300                         -0.719608                    -0.034179  \
# 3784100                          0.703190                    -0.294265
# 1192500                         -0.398347                    -0.554352
# 449400                          -0.533603                    -0.554352
# 2292700                         -0.303830                    -0.554352
# ...                                   ...                          ...
# 2440100                         -0.805969                    -0.034179
# 6487000                          0.241304                     0.225908
# 2493300                          0.398550                    -0.554352
# 1160000                         -0.465973                    -0.554352
# 3070300                         -0.772363                     1.266256
#
#          gq_other_p_ta  occ_unclassified_p_ta  com0811_p_ta  inrix_total_ta
# store
# 6150300       2.510505              -0.408704      3.304383       -0.587414  \
# 3784100       1.338613              -0.319611     -1.035261        1.135356
# 1192500      -0.744864               0.045673     -0.493172       -0.593298
# 449400       -0.151132              -0.141424     -0.425777       -0.999861
# 2292700      -0.471355              -0.399795      1.090608        2.300364
# ...                ...                    ...           ...             ...
# 2440100      -0.682918              -0.435432     -0.920983       -0.134447
# 6487000      -0.743172              -0.257245     -0.836007        0.289174
# 2493300      -0.614203              -0.301792      1.317699       -0.142035
# 1160000      -0.594570               0.981155      0.714076       -0.583812
# 3070300       0.576984              -0.123605      4.001774        0.897168
#
#          occ_bc_p_ta  ...  popgrfy_ta  hhgrfypy_ta  pop5y_cagr_ta  popgrpy_ta
# store                 ...
# 6150300    -0.418402  ...    0.002419    -0.012383      -0.629070   -0.622184  \
# 3784100     0.375126  ...    0.779724     0.805274       0.997839    0.968952
# 1192500     0.540203  ...   -0.512590    -0.518590      -0.343151   -0.349460
# 449400     -0.273598  ...   -0.291623    -0.290843      -0.187525   -0.199782
# 2292700     0.307068  ...   -0.386272    -0.378994      -0.344219   -0.350559
# ...              ...  ...         ...          ...            ...         ...
# 2440100    -0.151962  ...   -1.706438    -1.711277      -1.212880   -1.169971
# 6487000     0.159367  ...   -0.193105    -0.184894       0.055106    0.035201
# 2493300    -0.548726  ...   -0.598604    -0.604163      -0.333958   -0.340691
# 1160000    -0.923769  ...    0.135886     0.140763       0.184865    0.161849
# 3070300    -1.274196  ...   -0.366799    -0.367037      -0.226752   -0.237583
#
#          emp_p_ta  age85pl_p_ta  dmm_count_1mi  dmm_gla_1mi  wealth_hhavg_ta
# store
# 6150300 -1.404416     -0.226018      -0.462636    -0.408427        -1.073302  \
# 3784100 -1.655621      0.803634       0.637963     1.359225         0.284724
# 1192500  0.149498      0.021494       0.637963     1.139668         0.174865
# 449400  -0.014267      0.665027       0.637963     0.463615        -0.659364
# 2292700 -0.575217     -0.216118      -0.462636    -0.408427         0.042790
# ...           ...           ...            ...          ...              ...
# 2440100 -0.121715      0.635326      -0.462636    -0.408427        -0.227713
# 6487000  0.761578     -0.374526      -0.462636    -0.408427        -0.127952
# 2493300  0.282140      0.298708      -0.462636    -0.408427         0.130770
# 1160000 -1.256213      0.278907      -0.462636    -0.408427         0.028989
# 3070300 -1.151729     -0.562635       0.637963     0.210032        -2.718239
#
#          dtpop_unemployed_p_ta
# store
# 6150300               1.294902
# 3784100               0.353116
# 1192500               0.612588
# 449400                0.429997
# 2292700               0.775959
# ...                        ...
# 2440100               0.180135
# 6487000              -0.905801
# 2493300               0.324286
# 1160000              -0.896191
# 3070300               5.273465
#
# [12944 rows x 66 columns]

# %%
def corr_pair(target_corr, corr_threshold=0.6):
    np.fill_diagonal(target_corr.values, 0)
    sorted_pair = target_corr.abs().unstack().sort_values(kind="quicksort", ascending=False)
    return sorted_pair[sorted_pair > corr_threshold]

# %%
def corr_pair_drop(feature_pairs, corr_with_target):
    selected, discarded = [], []
    for f1, f2 in feature_pairs:
        if abs(corr_with_target[f1]) < abs(corr_with_target[f2]):
            selected.append(f2)
            discarded.append(f1)
        else:
            selected.append(f1)
            discarded.append(f2)
    final_discarded = set(discarded) - set(selected) 
    return list(final_discarded)

# %%
correlated_pairs = corr_pair(reduced_train.corr())
correlated_pairs[:40:2]
# Out:
# pop5y_cagr_ta                 popgrpy_ta                            0.999096
# hhgrfypy_ta                   popgrfy_ta                            0.998156
# hh_inc_lt_75k_p_ta            hh_inc_gt_75k_p_ta                    0.998023
# popgrpy_ta                    hhgrpycy_ta                           0.997022
# dtpop_students_p_ta           dtpop_students_post_secondary_p_ta    0.996903
# hhgrpycy_ta                   pop5y_cagr_ta                         0.996545
# dtpop_students_prek_8th_p_ta  dtpop_children_at_home_p_ta           0.991309
# hhinc100pl_p_ta               disposable_inc_avg_ta                 0.989117
# disposable_inc_avg_ta         medhhinc_ta                           0.984030
# medhhinc_ta                   hhinc100pl_p_ta                       0.978550
# hh_inc_gt_75k_p_ta            hhinc100pl_p_ta                       0.975142
# hh_inc_lt_75k_p_ta            hhinc100pl_p_ta                       0.973996
# disposable_inc_avg_ta         hh_inc_gt_75k_p_ta                    0.965990
# hh_inc_lt_75k_p_ta            disposable_inc_avg_ta                 0.964070
# medhhinc_ta                   hh_inc_gt_75k_p_ta                    0.960077
#                               hh_inc_lt_75k_p_ta                    0.958584
# hhinc30lt_p_ta                hh_inc_lt_75k_p_ta                    0.941599
#                               hh_inc_gt_75k_p_ta                    0.940278
# popgrfy_ta                    pop5y_cagr_ta                         0.921198
# pop5y_cagr_ta                 hhgrfypy_ta                           0.920426
# dtype: float64

# %%
corr_drop_list = corr_pair_drop(correlated_pairs.index, pca_feature_weight)
print(corr_drop_list)

# %%
reduced_train.drop(columns=corr_drop_list, inplace=True)
reduced_test.drop(columns=corr_drop_list, inplace=True)
# Out:
# /var/folders/t1/c4fmzstn5v92jwsl8z5vhpp40000gn/T/ipykernel_90595/1625573170.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_train.drop(columns=corr_drop_list, inplace=True)
# /var/folders/t1/c4fmzstn5v92jwsl8z5vhpp40000gn/T/ipykernel_90595/1625573170.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_test.drop(columns=corr_drop_list, inplace=True)

# %%
important_features = list(set(important_features) - set(corr_drop_list))

# %%
correlated_pairs = corr_pair(reduced_train.corr())
correlated_pairs[:20:2]
# Out:
# pop5y_cagr_ta          popgrpy_ta            0.999096
# hh_inc_lt_75k_p_ta     hh_inc_gt_75k_p_ta    0.998023
# hhgrpycy_ta            popgrpy_ta            0.997022
#                        pop5y_cagr_ta         0.996545
# disposable_inc_avg_ta  hhinc100pl_p_ta       0.989117
#                        medhhinc_ta           0.984030
# hhinc100pl_p_ta        medhhinc_ta           0.978550
#                        hh_inc_gt_75k_p_ta    0.975142
#                        hh_inc_lt_75k_p_ta    0.973996
# disposable_inc_avg_ta  hh_inc_gt_75k_p_ta    0.965990
# dtype: float64

# %%
corr_drop_list = corr_pair_drop(correlated_pairs.index, pca_feature_weight)
print(corr_drop_list)
# Out:
# ['hh_type_male_p_ta', 'hhinc30lt_p_ta', 'com12pl_p_ta', 'popgrpy_ta', 'dmm_gla_1mi', 'centerxy_gla_effective_5mi', 'dtpop_children_at_home_p_ta']

# %%
reduced_train.drop(columns=corr_drop_list, inplace=True)
reduced_test.drop(columns=corr_drop_list, inplace=True)
# Out:
# /var/folders/t1/c4fmzstn5v92jwsl8z5vhpp40000gn/T/ipykernel_90595/1625573170.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_train.drop(columns=corr_drop_list, inplace=True)
# /var/folders/t1/c4fmzstn5v92jwsl8z5vhpp40000gn/T/ipykernel_90595/1625573170.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_test.drop(columns=corr_drop_list, inplace=True)

# %%
correlated_pairs = corr_pair(reduced_train.corr())
correlated_pairs[:20:2]
# Out:
# hh_inc_lt_75k_p_ta     hh_inc_gt_75k_p_ta       0.998023
# hhgrpycy_ta            pop5y_cagr_ta            0.996545
# disposable_inc_avg_ta  hhinc100pl_p_ta          0.989117
# medhhinc_ta            disposable_inc_avg_ta    0.984030
#                        hhinc100pl_p_ta          0.978550
# hh_inc_gt_75k_p_ta     hhinc100pl_p_ta          0.975142
# hh_inc_lt_75k_p_ta     hhinc100pl_p_ta          0.973996
# disposable_inc_avg_ta  hh_inc_gt_75k_p_ta       0.965990
#                        hh_inc_lt_75k_p_ta       0.964070
# hh_inc_gt_75k_p_ta     medhhinc_ta              0.960077
# dtype: float64

# %%
corr_drop_list = corr_pair_drop(correlated_pairs.index, pca_feature_weight)
print(corr_drop_list)
# Out:
# ['hh_inc_lt_75k_p_ta', 'hhgrfypy_ta']

# %%
reduced_train.drop(columns=corr_drop_list, inplace=True)
reduced_test.drop(columns=corr_drop_list, inplace=True)
# Out:
# /var/folders/t1/c4fmzstn5v92jwsl8z5vhpp40000gn/T/ipykernel_90595/1625573170.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_train.drop(columns=corr_drop_list, inplace=True)
# /var/folders/t1/c4fmzstn5v92jwsl8z5vhpp40000gn/T/ipykernel_90595/1625573170.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_test.drop(columns=corr_drop_list, inplace=True)

# %%
correlated_pairs = corr_pair(reduced_train.corr())
correlated_pairs[:20:2]
# Out:
# pop5y_cagr_ta          hhgrpycy_ta              0.996545
# disposable_inc_avg_ta  hhinc100pl_p_ta          0.989117
# medhhinc_ta            disposable_inc_avg_ta    0.984030
# hhinc100pl_p_ta        medhhinc_ta              0.978550
# hh_inc_gt_75k_p_ta     hhinc100pl_p_ta          0.975142
#                        disposable_inc_avg_ta    0.965990
#                        medhhinc_ta              0.960077
# dtype: float64

# %%
corr_drop_list = corr_pair_drop(correlated_pairs.index, pca_feature_weight)
print(corr_drop_list)
# Out:
# ['pop5y_cagr_ta', 'hh_inc_gt_75k_p_ta']

# %%
reduced_train.drop(columns=corr_drop_list, inplace=True)
reduced_test.drop(columns=corr_drop_list, inplace=True)
# Out:
# /var/folders/t1/c4fmzstn5v92jwsl8z5vhpp40000gn/T/ipykernel_90595/1625573170.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_train.drop(columns=corr_drop_list, inplace=True)
# /var/folders/t1/c4fmzstn5v92jwsl8z5vhpp40000gn/T/ipykernel_90595/1625573170.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_test.drop(columns=corr_drop_list, inplace=True)

# %%
pf.pca_plot(reduced_train, n_components=20)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 pf.pca_plot(reduced_train, n_components=20)
#
# File ~/Desktop/UBC/Restaurant_Segmentation_Analysis/doc/subway_us/../../src/./plotting_functions.py:156, in pca_plot(train_data, n_components)
#     154 plt.grid()
#     155 plt.show()
# --> 156 return num_comp
#
# UnboundLocalError: local variable 'num_comp' referenced before assignment

# %%
pca_2 = PCA(n_components=11, whiten=True, random_state=42)
pca_2.fit(reduced_train)
# Out:
# PCA(n_components=11, random_state=42, whiten=True)

# %% [markdown]
# #### Filter and Count Important Features (of heavy weights)
#
# Filter the values in the PCA component matrix, and count the occurrence of the features in the filtered matrix.

# %%
W = abs(pca_2.components_)
features = reduced_train.columns
long_results = []
for i in range(W.shape[0]):
    array = W[i]
    heavy_idx = np.where(array > 0.15)
    long_results += list(features[heavy_idx])

# %%
count = pd.Series(long_results).value_counts()
count
# Out:
# market_size                                         7
# hh_type_nonfam_p_ta                                 6
# occ_military_p_ta                                   5
# genz_p_ta                                           5
# dmm_count_1mi                                       4
# age85pl_p_ta                                        4
# centerxy_gla_effective_2mi                          4
# com12pl_p_ta                                        4
# dmm_gla_2mi                                         4
# ipeds_postsecondary_schools_total_enrollment_2mi    4
# dtpop_students_post_secondary_p_ta                  4
# occ_bc_p_ta                                         4
# white_p_ta                                          3
# dmm_gla_1mi                                         3
# military_installations_3mi                          3
# military_installations_1mi                          3
# com0811_p_ta                                        3
# dtpop_children_at_home_p_ta                         3
# military_installations_5mi                          3
# nces_private_schools_1mi                            3
# black_p_ta                                          3
# hh_type_female_p_ta                                 3
# other_p_ta                                          3
# pop5y_cagr_ta                                       2
# occ_unclassified_p_ta                               2
# transitstop_nearest_dist                            2
# genx_p_ta                                           2
# gq_other_p_ta                                       2
# hrsa_number_of_certified_beds_1mi                   2
# hrsa_hospitals_nearest_dist                         2
# dmm_nearest_dist                                    2
# popgrfy_ta                                          2
# hhgrfypy_ta                                         2
# medsalcy_ta                                         2
# osm_highway_exits_count_2mi                         2
# hh_type_female_nochild_p_ta                         2
# hh_type_male_p_ta                                   2
# popgrpy_ta                                          2
# inrix_total_ta                                      1
# hhinc100pl_p_ta                                     1
# medhhinc_ta                                         1
# hh_inc_lt_75k_p_ta                                  1
# disposable_inc_avg_ta                               1
# hh_inc_gt_75k_p_ta                                  1
# hhinc30lt_p_ta                                      1
# avg_faminc_ta                                       1
# nces_public_schools_nearest_dist                    1
# Name: count, dtype: int64

# %%
pca_2_features = count.index.tolist()

# %%
weighted_W = pca_2.explained_variance_ratio_ * W.T
pca_2_feature_weight = pd.Series(np.sum(weighted_W, axis=1), index=reduced_train.columns.tolist())
pca_2_feature_weight = pca_2_feature_weight.filter(items=pca_2_features, axis=0)
pca_2_feature_weight.sort_values(ascending=False, inplace=True)
pca_2_feature_weight
# Out:
# inrix_total_ta                                      0.698371
# market_size                                         0.109998
# dmm_gla_2mi                                         0.045684
# centerxy_gla_effective_2mi                          0.044329
# white_p_ta                                          0.042552
# dmm_count_1mi                                       0.041124
# dmm_gla_1mi                                         0.040779
# dmm_nearest_dist                                    0.040001
# disposable_inc_avg_ta                               0.039145
# genx_p_ta                                           0.038663
# hhinc100pl_p_ta                                     0.038130
# hh_inc_gt_75k_p_ta                                  0.037762
# hh_inc_lt_75k_p_ta                                  0.037706
# popgrfy_ta                                          0.037641
# hh_type_female_nochild_p_ta                         0.037574
# hhgrfypy_ta                                         0.037565
# medhhinc_ta                                         0.037521
# avg_faminc_ta                                       0.037434
# hhinc30lt_p_ta                                      0.036607
# hh_type_female_p_ta                                 0.036335
# pop5y_cagr_ta                                       0.034917
# popgrpy_ta                                          0.034799
# osm_highway_exits_count_2mi                         0.031971
# transitstop_nearest_dist                            0.031024
# ipeds_postsecondary_schools_total_enrollment_2mi    0.030180
# nces_private_schools_1mi                            0.030170
# hh_type_male_p_ta                                   0.030105
# hh_type_nonfam_p_ta                                 0.029882
# hrsa_hospitals_nearest_dist                         0.029146
# age85pl_p_ta                                        0.028886
# genz_p_ta                                           0.028265
# black_p_ta                                          0.027820
# medsalcy_ta                                         0.027629
# com0811_p_ta                                        0.027397
# military_installations_5mi                          0.026288
# occ_bc_p_ta                                         0.025569
# military_installations_3mi                          0.024714
# occ_unclassified_p_ta                               0.024656
# gq_other_p_ta                                       0.024072
# com12pl_p_ta                                        0.023957
# dtpop_students_post_secondary_p_ta                  0.023898
# hrsa_number_of_certified_beds_1mi                   0.023141
# dtpop_children_at_home_p_ta                         0.020475
# occ_military_p_ta                                   0.016007
# military_installations_1mi                          0.016007
# nces_public_schools_nearest_dist                    0.014677
# other_p_ta                                          0.012109
# dtype: float64

# %%
pca_2_feature_weight = pca_2_feature_weight.sort_values(ascending=False)
important_features_2 = pca_2_feature_weight[:40].index.tolist()

# %%
important_features = list(set(important_features + important_features_2))

# %%
reduced_train = reduced_train[important_features]
reduced_test = reduced_test[important_features]
reduced_train
# Out:
#          dtpop_students_post_secondary_p_ta  pop5y_cagr_ta  hh_type_male_p_ta
# store
# 6150300                           -0.247143      -0.629070           1.041346  \
# 3784100                           -0.163931       0.997839          -0.046505
# 1192500                           -0.514482      -0.343151          -0.167916
# 449400                            -0.287863      -0.187525           0.477995
# 2292700                            0.301700      -0.344219           0.783953
# ...                                     ...            ...                ...
# 2440100                           -0.542810      -1.212880          -0.527296
# 6487000                            0.558417       0.055106           0.249740
# 2493300                           -0.544580      -0.333958          -0.221338
# 1160000                           -0.156849       0.184865          -0.852679
# 3070300                            0.652251      -0.226752           1.857233
#
#          occ_unclassified_p_ta  occ_bc_p_ta  nces_public_schools_nearest_dist
# store
# 6150300              -0.408704    -0.418402                         -0.719608  \
# 3784100              -0.319611     0.375126                          0.703190
# 1192500               0.045673     0.540203                         -0.398347
# 449400               -0.141424    -0.273598                         -0.533603
# 2292700              -0.399795     0.307068                         -0.303830
# ...                        ...          ...                               ...
# 2440100              -0.435432    -0.151962                         -0.805969
# 6487000              -0.257245     0.159367                          0.241304
# 2493300              -0.301792    -0.548726                          0.398550
# 1160000               0.981155    -0.923769                         -0.465973
# 3070300              -0.123605    -1.274196                         -0.772363
#
#          hh_type_nonfam_p_ta  com12pl_p_ta  popgrpy_ta  dmm_count_1mi  ...
# store                                                                  ...
# 6150300            -1.109287      0.148031   -0.622184      -0.462636  ...  \
# 3784100            -0.371554      0.258930    0.968952       0.637963  ...
# 1192500             0.366179      0.312257   -0.349460       0.637963  ...
# 449400              0.143518      0.076772   -0.199782       0.637963  ...
# 2292700            -0.645186      0.931878   -0.350559      -0.462636  ...
# ...                      ...           ...         ...            ...  ...
# 2440100            -0.103288     -0.524916   -1.169971      -0.462636  ...
# 6487000            -0.578119     -0.904806    0.035201      -0.462636  ...
# 2493300             1.028797     -0.889705   -0.340691      -0.462636  ...
# 1160000            -0.841020      0.546325    0.161849      -0.462636  ...
# 3070300            -0.438621     -1.358786   -0.237583       0.637963  ...
#
#          genz_p_ta  occ_military_p_ta  dmm_gla_1mi  white_p_ta
# store
# 6150300   0.185124           -0.12575    -0.408427   -1.749451  \
# 3784100  -0.207241           -0.12575     1.359225    0.029789
# 1192500  -0.469702           -0.12575     1.139668    0.457056
# 449400   -0.183381           -0.12575     0.463615    0.363884
# 2292700   0.177171           -0.12575    -0.408427   -1.577531
# ...            ...                ...          ...         ...
# 2440100  -0.649978           -0.12575    -0.408427    1.167739
# 6487000   0.357447           -0.12575    -0.408427   -0.164352
# 2493300  -0.649978           -0.12575    -0.408427    1.018819
# 1160000  -0.053476           -0.12575    -0.408427    1.349015
# 3070300   0.262007           -0.12575     0.210032   -2.219211
#
#          hh_inc_lt_75k_p_ta  black_p_ta  hhgrfypy_ta  gq_other_p_ta
# store
# 6150300            1.280023   -0.325387    -0.012383       2.510505  \
# 3784100            0.090226    0.081633     0.805274       1.338613
# 1192500           -0.255337   -0.472435    -0.518590      -0.744864
# 449400             0.574587   -0.546890    -0.290843      -0.151132
# 2292700           -0.731828   -0.654849    -0.378994      -0.471355
# ...                     ...         ...          ...            ...
# 2440100            0.697645   -0.551233    -1.711277      -0.682918
# 6487000            0.481579    1.251193    -0.184894      -0.743172
# 2493300           -0.265354   -0.649885    -0.604163      -0.614203
# 1160000            0.548831   -0.717515     0.140763      -0.594570
# 3070300            1.376609    0.607159    -0.367037       0.576984
#
#          dmm_gla_2mi  hh_type_female_nochild_p_ta
# store
# 6150300    -0.434744                     1.888641
# 3784100     0.371039                     0.268583
# 1192500     0.639123                    -0.354001
# 449400      0.745324                     0.007500
# 2292700    -0.049046                     1.256015
# ...              ...                          ...
# 2440100    -0.611623                     0.318792
# 6487000     1.362032                    -0.056098
# 2493300     0.005481                    -0.745626
# 1160000    -0.611623                    -0.815918
# 3070300    -0.267813                     2.922933
#
# [12944 rows x 45 columns]

# %%
def corr_pair(target_corr, corr_threshold=0.6):
    np.fill_diagonal(target_corr.values, 0)
    sorted_pair = target_corr.abs().unstack().sort_values(kind="quicksort", ascending=False)
    return sorted_pair[sorted_pair > corr_threshold]

correlated_pairs = corr_pair(reduced_train.corr())

# %%
correlated_pairs[:40:2]
# Out:
# popgrpy_ta             pop5y_cagr_ta         0.999096
# hhgrfypy_ta            popgrfy_ta            0.998156
# hh_inc_lt_75k_p_ta     hh_inc_gt_75k_p_ta    0.998023
# disposable_inc_avg_ta  hhinc100pl_p_ta       0.989117
#                        medhhinc_ta           0.984030
# medhhinc_ta            hhinc100pl_p_ta       0.978550
# hhinc100pl_p_ta        hh_inc_gt_75k_p_ta    0.975142
# disposable_inc_avg_ta  avg_faminc_ta         0.974317
# hhinc100pl_p_ta        hh_inc_lt_75k_p_ta    0.973996
# avg_faminc_ta          hhinc100pl_p_ta       0.966812
# disposable_inc_avg_ta  hh_inc_gt_75k_p_ta    0.965990
#                        hh_inc_lt_75k_p_ta    0.964070
# hh_inc_gt_75k_p_ta     medhhinc_ta           0.960077
# medhhinc_ta            hh_inc_lt_75k_p_ta    0.958584
# avg_faminc_ta          medhhinc_ta           0.952972
# hhinc30lt_p_ta         hh_inc_lt_75k_p_ta    0.941599
# hh_inc_gt_75k_p_ta     hhinc30lt_p_ta        0.940278
#                        avg_faminc_ta         0.935531
# hh_inc_lt_75k_p_ta     avg_faminc_ta         0.933600
# popgrfy_ta             pop5y_cagr_ta         0.921198
# dtype: float64

# %%
print(pca_feature_weight['military_installations_5mi'], pca_feature_weight['military_installations_3mi'])
print(pca_feature_weight['centerxy_gla_effective_1mi'], pca_feature_weight['dmm_gla_1mi'])
print(pca_feature_weight['osm_highway_exits_count_2mi'], pca_feature_weight['osm_highway_exits_count_1mi'])
# Out:
# 0.03782548252596881 0.041533142106797136
# 0.036444494335065775 0.03868716193509502
# 0.04243214809911437 0.03517307532439087

# %%
corr_drop_list = ['dmm_count_1mi', 'military_installations_5mi', 'dmm_gla_1mi', 'osm_highway_exits_count_1mi', 'hrsa_hospitals_1mi']

# %%
reduced_train.drop(columns=corr_drop_list, inplace=True)
reduced_test.drop(columns=corr_drop_list, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 reduced_train.drop(columns=corr_drop_list, inplace=True)
#       2 reduced_test.drop(columns=corr_drop_list, inplace=True)
#
# File ~/miniconda3/envs/cap/lib/python3.8/site-packages/pandas/core/frame.py:5268, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5120 def drop(
#    5121     self,
#    5122     labels: IndexLabel = None,
#    (...)
#    5129     errors: IgnoreRaise = "raise",
#    5130 ) -> DataFrame | None:
#    5131     """
#    5132     Drop specified labels from rows or columns.
#    5133
#    (...)
#    5266             weight  1.0     0.8
#    5267     """
# -> 5268     return super().drop(
#    5269         labels=labels,
#    5270         axis=axis,
#    5271         index=index,
#    5272         columns=columns,
#    5273         level=level,
#    5274         inplace=inplace,
#    5275         errors=errors,
#    5276     )
#
# File ~/miniconda3/envs/cap/lib/python3.8/site-packages/pandas/core/generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~/miniconda3/envs/cap/lib/python3.8/site-packages/pandas/core/generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~/miniconda3/envs/cap/lib/python3.8/site-packages/pandas/core/indexes/base.py:6696, in Index.drop(self, labels, errors)
#    6694 if mask.any():
#    6695     if errors != "ignore":
# -> 6696         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6697     indexer = indexer[~mask]
#    6698 return self.delete(indexer)
#
# KeyError: "['military_installations_5mi', 'osm_highway_exits_count_1mi', 'hrsa_hospitals_1mi'] not found in axis"

# %%
correlated_pairs = corr_pair(reduced_train.corr())
correlated_pairs[:100:2]
