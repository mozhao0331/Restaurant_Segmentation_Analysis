# %%
import pandas as pd
import numpy as np
from lightgbm.sklearn import LGBMClassifier
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler
from sklearn.compose import make_column_transformer

# %%
DIR = "../data/"
SMOOTHIE = "Smoothie King/smoothie_king_"

# %%
smoothie_demographic = pd.read_csv(DIR + SMOOTHIE + "demographic_variables.csv")
smoothie_stores = pd.read_csv(DIR + SMOOTHIE + "stores.csv")
smoothie_poi_variables = pd.read_csv(DIR + SMOOTHIE + "poi_variables.csv")
smoothie_demographic
# Out:
#        store  medhhinc_1mi  age0018_1mi  age0018_p_1mi  age65pl_1mi  \
# 0    SK 1504    83846.0042       3774.0         0.2969       1151.0
# 1    SK 0057    50388.0216       1688.0         0.2298       1311.0
# 2    SK 1415    59999.1012       3340.0         0.2405       2451.0
# 3    SK 1231    97438.8015       2266.0         0.1938       2476.0
# 4    SK 1535    56156.2657       9780.0         0.3207       2628.0
# ..       ...           ...          ...            ...          ...
# 791  SK 1536    32998.8647       3424.0         0.3104       1395.0
# 792  SK 1886    55847.7090       2590.0         0.1828       1542.0
# 793  SK 0162    51203.5596       1878.0         0.2856       1024.0
# 794  SK 1449    50153.8368       2000.0         0.2824        847.0
# 795  SK 1351   116040.1330        706.0         0.2312        371.0
#
#      age65pl_p_1mi  age85pl_1mi  age85pl_p_1mi  asian_1mi  asian_p_1mi  ...  \
# 0           0.0905         57.0         0.0045   603.0579       0.0474  ...
# 1           0.1784        123.0         0.0168   280.1880       0.0381  ...
# 2           0.1765        194.0         0.0140   167.5000       0.0121  ...
# 3           0.2118        224.0         0.0192   414.8301       0.0355  ...
# 4           0.0862         91.0         0.0030  2148.1145       0.0705  ...
# ..             ...          ...            ...        ...          ...  ...
# 791         0.1265         98.0         0.0089    79.8703       0.0072  ...
# 792         0.1089        229.0         0.0162   556.5048       0.0393  ...
# 793         0.1558        126.0         0.0191    84.8653       0.0129  ...
# 794         0.1196         84.0         0.0118   181.6803       0.0257  ...
# 795         0.1215         21.0         0.0070   190.1256       0.0623  ...
#
#      poverty_inpoverty_10mi  poverty_inpoverty_p_10mi  \
# 0                   15484.0                    0.0640
# 1                   21823.0                    0.1813
# 2                   10340.0                    0.0608
# 3                   59470.0                    0.1408
# 4                   37120.0                    0.0775
# ..                      ...                       ...
# 791                 37636.0                    0.1624
# 792                 12511.0                    0.1215
# 793                  9097.0                    0.0881
# 794                 21515.0                    0.1795
# 795                 27866.0                    0.1074
#
#      spend_breakfastbrunch_10mi  spend_dinner_10mi  spend_foodbev_10mi  \
# 0                    62995242.0        364526249.0        2.039742e+09
# 1                    27814428.0        149355911.0        9.420898e+08
# 2                    41122434.0        231354667.0        1.394461e+09
# 3                   102293013.0        554039317.0        3.620776e+09
# 4                   115249938.0        662800687.0        4.112360e+09
# ..                          ...                ...                 ...
# 791                  66296019.0        359428431.0        2.322572e+09
# 792                  23624568.0        134117651.0        9.156644e+08
# 793                  25916308.0        146563993.0        9.092607e+08
# 794                  30289183.0        161335026.0        1.031824e+09
# 795                  63450510.0        358440051.0        2.031044e+09
#
#      spend_lunch_10mi  wealth_hhavg_10mi  wealth_hhtotal_10mi   white_10mi  \
# 0         205361587.0           244674.0             241941.0  332706.8340
# 1          86239896.0           221080.0             120338.0  160816.1504
# 2         131310533.0           252962.0             169964.0  343932.2978
# 3         317547521.0           230357.0             422361.0  400703.7973
# 4         370573539.0           245089.0             479049.0  580244.6476
# ..                ...                ...                  ...          ...
# 791       207584850.0           212492.0             231740.0  116424.0527
# 792        76271730.0           248551.0             102970.0  214301.5774
# 793        82836656.0           249492.0             103313.0  192989.8084
# 794        93613567.0           210307.0             119859.0  129891.1147
# 795       203348840.0           238440.0             259471.0  275738.0828
#
#      white_p_10mi
# 0          0.5118
# 1          0.5205
# 2          0.8088
# 3          0.3940
# 4          0.4906
# ..            ...
# 791        0.1615
# 792        0.8203
# 793        0.6788
# 794        0.4147
# 795        0.4187
#
# [796 rows x 966 columns]

# %%
smoothie_poi_variables
# Out:
#        store  centerxy_gla_1mi  centerxy_count_1mi  centerxy_gla_2mi  \
# 0    SK 1504          198023.0                   1          307544.0
# 1    SK 0057          253302.0                   2         1002488.0
# 2    SK 1415          715612.0                   3         1361502.0
# 3    SK 1231          415300.0                   2          588410.0
# 4    SK 1535          308913.0                   2         1148114.0
# ..       ...               ...                 ...               ...
# 791  SK 1536         1333256.0                   5         1921864.0
# 792  SK 1886          367642.0                   2         1734971.0
# 793  SK 0162          628704.0                   3         1294244.0
# 794  SK 1449         3191061.0                   8         3463831.0
# 795  SK 1351         1800000.0                   1         3046938.0
#
#      centerxy_count_2mi  centerxy_gla_3mi  centerxy_count_3mi  \
# 0                     2         1969648.0                  11
# 1                     7         3381962.0                  11
# 2                     7         2027580.0                  10
# 3                     3         1850924.0                   5
# 4                     7         3823444.0                  13
# ..                  ...               ...                 ...
# 791                   9         2043636.0                  10
# 792                   7         2749951.0                  13
# 793                   7         2641385.0                  11
# 794                  10         4154627.0                  13
# 795                   2         3183509.0                   3
#
#      centerxy_gla_5mi  centerxy_count_5mi  centerxy_gla_10mi  ...  \
# 0           5770569.0                  20         15317967.0  ...
# 1           5522926.0                  20          6507331.0  ...
# 2           4001581.0                  16         13191004.0  ...
# 3           4825186.0                  14         21089283.0  ...
# 4          10583744.0                  45         36941461.0  ...
# ..                ...                 ...                ...  ...
# 791         3504457.0                  16          8561361.0  ...
# 792         4156741.0                  17          4538137.0  ...
# 793         2922800.0                  12          4807504.0  ...
# 794         4450657.0                  15          5950658.0  ...
# 795         5044469.0                   9         16969415.0  ...
#
#      nces_public_schools_total_enrollment_10mi  nces_public_schools_10mi  \
# 0                                     110757.0                       174
# 1                                      45635.0                        78
# 2                                      55532.0                        96
# 3                                     121834.0                       184
# 4                                     179702.0                       280
# ..                                         ...                       ...
# 791                                   136369.0                       254
# 792                                    36249.0                        67
# 793                                    48840.0                        61
# 794                                    41121.0                        75
# 795                                    88740.0                       128
#
#      osm_nearest_exit_dist  osm_highway_exits_count_1mi  \
# 0                 1.875541                            0
# 1                 2.617072                            0
# 2                 0.194937                            2
# 3                 1.393043                            0
# 4                 0.711949                            3
# ..                     ...                          ...
# 791               0.261721                           14
# 792               4.012518                            0
# 793               0.397305                            4
# 794               0.706073                            5
# 795               0.578092                            4
#
#      osm_highway_exits_count_2mi  osm_highway_exits_count_3mi  \
# 0                              2                           17
# 1                              0                            3
# 2                              8                           25
# 3                              6                           31
# 4                             14                           23
# ..                           ...                          ...
# 791                           23                           36
# 792                            0                            0
# 793                           11                           15
# 794                            7                           12
# 795                           20                           32
#
#      osm_highway_exits_count_5mi  osm_highway_exits_count_10mi  \
# 0                             45                           123
# 1                             14                            58
# 2                             45                           162
# 3                             61                           114
# 4                             72                           366
# ..                           ...                           ...
# 791                           81                           258
# 792                           10                            17
# 793                           23                            38
# 794                           46                           109
# 795                           42                           144
#
#      transitstop_nearest_dist  transitstops
# 0                   14.818824             0
# 1                   49.572856             0
# 2                    3.518308             0
# 3                    0.021790            25
# 4                    0.055289            17
# ..                        ...           ...
# 791                  0.012345            24
# 792                  0.189059            13
# 793                  0.699036             0
# 794                  4.771075             0
# 795                  0.286296             4
#
# [796 rows x 142 columns]

# %%
smoothie_merged = smoothie_stores.merge(smoothie_demographic).merge(smoothie_poi_variables)
smoothie_merged
# Out:
#        store   longitude   latitude  category  \
# 0    SK 1504  -97.650392  30.519353  SHOPPING
# 1    SK 0057  -88.171150  30.672501  SHOPPING
# 2    SK 1415  -90.535722  38.784250      HOME
# 3    SK 1231  -80.134700  26.100737    TRAVEL
# 4    SK 1535  -96.856651  32.996408      WORK
# ..       ...         ...        ...       ...
# 791  SK 1536  -96.872596  32.647809      HOME
# 792  SK 1886 -105.077634  40.564695     OTHER
# 793  SK 0162  -95.478001  30.316531  SHOPPING
# 794  SK 1449  -78.968258  35.064994  SHOPPING
# 795  SK 1351  -98.605570  29.616600      HOME
#
#                            cbsa_name                  dma_name  \
# 0              Austin-Round Rock, TX                Austin, TX
# 1                         Mobile, AL       Mobile et al, AL-FL
# 2                   St. Louis, MO-IL             St. Louis, MO
# 3    Miami-Fort Lauderdale et al, FL  Miami-Ft. Lauderdale, FL
# 4    Dallas-Fort Worth-Arlington, TX      Dallas-Ft. Worth, TX
# ..                               ...                       ...
# 791  Dallas-Fort Worth-Arlington, TX      Dallas-Ft. Worth, TX
# 792                 Fort Collins, CO                Denver, CO
# 793  Houston-The Woodlands et al, TX               Houston, TX
# 794                 Fayetteville, NC         Raleigh et al, NC
# 795    San Antonio-New Braunfels, TX           San Antonio, TX
#
#          state_name           market_size   store_density  medhhinc_1mi  ...  \
# 0             Texas       Large Metro (2)  Light Suburban    83846.0042  ...
# 1           Alabama       Medium City (4)  Light Suburban    50388.0216  ...
# 2          Missouri  Very Large Metro (1)  Light Suburban    59999.1012  ...
# 3           Florida  Very Large Metro (1)        Suburban    97438.8015  ...
# 4             Texas  Very Large Metro (1)  Light Suburban    56156.2657  ...
# ..              ...                   ...             ...           ...  ...
# 791           Texas  Very Large Metro (1)         Exurban    32998.8647  ...
# 792        Colorado       Medium City (4)  Light Suburban    55847.7090  ...
# 793           Texas  Very Large Metro (1)         Exurban    51203.5596  ...
# 794  North Carolina       Medium City (4)         Exurban    50153.8368  ...
# 795           Texas  Very Large Metro (1)         Exurban   116040.1330  ...
#
#      nces_public_schools_total_enrollment_10mi  nces_public_schools_10mi  \
# 0                                     110757.0                       174
# 1                                      45635.0                        78
# 2                                      55532.0                        96
# 3                                     121834.0                       184
# 4                                     179702.0                       280
# ..                                         ...                       ...
# 791                                   136369.0                       254
# 792                                    36249.0                        67
# 793                                    48840.0                        61
# 794                                    41121.0                        75
# 795                                    88740.0                       128
#
#      osm_nearest_exit_dist  osm_highway_exits_count_1mi  \
# 0                 1.875541                            0
# 1                 2.617072                            0
# 2                 0.194937                            2
# 3                 1.393043                            0
# 4                 0.711949                            3
# ..                     ...                          ...
# 791               0.261721                           14
# 792               4.012518                            0
# 793               0.397305                            4
# 794               0.706073                            5
# 795               0.578092                            4
#
#      osm_highway_exits_count_2mi  osm_highway_exits_count_3mi  \
# 0                              2                           17
# 1                              0                            3
# 2                              8                           25
# 3                              6                           31
# 4                             14                           23
# ..                           ...                          ...
# 791                           23                           36
# 792                            0                            0
# 793                           11                           15
# 794                            7                           12
# 795                           20                           32
#
#      osm_highway_exits_count_5mi  osm_highway_exits_count_10mi  \
# 0                             45                           123
# 1                             14                            58
# 2                             45                           162
# 3                             61                           114
# 4                             72                           366
# ..                           ...                           ...
# 791                           81                           258
# 792                           10                            17
# 793                           23                            38
# 794                           46                           109
# 795                           42                           144
#
#      transitstop_nearest_dist  transitstops
# 0                   14.818824             0
# 1                   49.572856             0
# 2                    3.518308             0
# 3                    0.021790            25
# 4                    0.055289            17
# ..                        ...           ...
# 791                  0.012345            24
# 792                  0.189059            13
# 793                  0.699036             0
# 794                  4.771075             0
# 795                  0.286296             4
#
# [796 rows x 1115 columns]

# %%
smoothie_merged = smoothie_merged.drop(columns=["store", "longitude", "latitude", "cbsa_name"])
smoothie_merged
# Out:
#      category                  dma_name      state_name           market_size  \
# 0    SHOPPING                Austin, TX           Texas       Large Metro (2)
# 1    SHOPPING       Mobile et al, AL-FL         Alabama       Medium City (4)
# 2        HOME             St. Louis, MO        Missouri  Very Large Metro (1)
# 3      TRAVEL  Miami-Ft. Lauderdale, FL         Florida  Very Large Metro (1)
# 4        WORK      Dallas-Ft. Worth, TX           Texas  Very Large Metro (1)
# ..        ...                       ...             ...                   ...
# 791      HOME      Dallas-Ft. Worth, TX           Texas  Very Large Metro (1)
# 792     OTHER                Denver, CO        Colorado       Medium City (4)
# 793  SHOPPING               Houston, TX           Texas  Very Large Metro (1)
# 794  SHOPPING         Raleigh et al, NC  North Carolina       Medium City (4)
# 795      HOME           San Antonio, TX           Texas  Very Large Metro (1)
#
#       store_density  medhhinc_1mi  age0018_1mi  age0018_p_1mi  age65pl_1mi  \
# 0    Light Suburban    83846.0042       3774.0         0.2969       1151.0
# 1    Light Suburban    50388.0216       1688.0         0.2298       1311.0
# 2    Light Suburban    59999.1012       3340.0         0.2405       2451.0
# 3          Suburban    97438.8015       2266.0         0.1938       2476.0
# 4    Light Suburban    56156.2657       9780.0         0.3207       2628.0
# ..              ...           ...          ...            ...          ...
# 791         Exurban    32998.8647       3424.0         0.3104       1395.0
# 792  Light Suburban    55847.7090       2590.0         0.1828       1542.0
# 793         Exurban    51203.5596       1878.0         0.2856       1024.0
# 794         Exurban    50153.8368       2000.0         0.2824        847.0
# 795         Exurban   116040.1330        706.0         0.2312        371.0
#
#      age65pl_p_1mi  ...  nces_public_schools_total_enrollment_10mi  \
# 0           0.0905  ...                                   110757.0
# 1           0.1784  ...                                    45635.0
# 2           0.1765  ...                                    55532.0
# 3           0.2118  ...                                   121834.0
# 4           0.0862  ...                                   179702.0
# ..             ...  ...                                        ...
# 791         0.1265  ...                                   136369.0
# 792         0.1089  ...                                    36249.0
# 793         0.1558  ...                                    48840.0
# 794         0.1196  ...                                    41121.0
# 795         0.1215  ...                                    88740.0
#
#      nces_public_schools_10mi  osm_nearest_exit_dist  \
# 0                         174               1.875541
# 1                          78               2.617072
# 2                          96               0.194937
# 3                         184               1.393043
# 4                         280               0.711949
# ..                        ...                    ...
# 791                       254               0.261721
# 792                        67               4.012518
# 793                        61               0.397305
# 794                        75               0.706073
# 795                       128               0.578092
#
#      osm_highway_exits_count_1mi  osm_highway_exits_count_2mi  \
# 0                              0                            2
# 1                              0                            0
# 2                              2                            8
# 3                              0                            6
# 4                              3                           14
# ..                           ...                          ...
# 791                           14                           23
# 792                            0                            0
# 793                            4                           11
# 794                            5                            7
# 795                            4                           20
#
#      osm_highway_exits_count_3mi  osm_highway_exits_count_5mi  \
# 0                             17                           45
# 1                              3                           14
# 2                             25                           45
# 3                             31                           61
# 4                             23                           72
# ..                           ...                          ...
# 791                           36                           81
# 792                            0                           10
# 793                           15                           23
# 794                           12                           46
# 795                           32                           42
#
#      osm_highway_exits_count_10mi  transitstop_nearest_dist  transitstops
# 0                             123                 14.818824             0
# 1                              58                 49.572856             0
# 2                             162                  3.518308             0
# 3                             114                  0.021790            25
# 4                             366                  0.055289            17
# ..                            ...                       ...           ...
# 791                           258                  0.012345            24
# 792                            17                  0.189059            13
# 793                            38                  0.699036             0
# 794                           109                  4.771075             0
# 795                           144                  0.286296             4
#
# [796 rows x 1111 columns]

# %%
train_df, test_df = train_test_split(smoothie_merged, test_size=0.2, random_state=42)
X_train = train_df.drop(columns=["category"])
y_train = train_df["category"]
X_test = test_df.drop(columns=["category"])
y_test = test_df["category"]

# %%
X_train["store_density"].unique()
# Out:
# array(['Light Suburban', 'Exurban', 'Rural', 'Suburban', 'Light Urban',
#        'Urban', 'Super Urban'], dtype=object)

# %%
categorical_features = ["dma_name", "store_density", "state_name"]
ordinal_features = ["market_size"]
numeric_features = X_train.select_dtypes(include=[np.number]).columns.tolist()

# %%
market_levels = [
    "Small Town (6)",
    "Small City (5)",
    "Medium City (4)",
    "Large City (3)",
    "Large Metro (2)",
    "Very Large Metro (1)"
]

ordinal_transformer = OrdinalEncoder(categories=[market_levels], dtype=int)
    
preprocessor = make_column_transformer(
    (StandardScaler(), numeric_features),
    (ordinal_transformer, ordinal_features),
    (OneHotEncoder(handle_unknown="ignore", sparse=False), categorical_features)
)
pipe = make_pipeline(
    preprocessor,
    LGBMClassifier(random_state=42)
)
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('standardscaler',
#                                                   StandardScaler(),
#                                                   ['medhhinc_1mi',
#                                                    'age0018_1mi',
#                                                    'age0018_p_1mi',
#                                                    'age65pl_1mi',
#                                                    'age65pl_p_1mi',
#                                                    'age85pl_1mi',
#                                                    'age85pl_p_1mi', 'asian_1mi',
#                                                    'asian_p_1mi',
#                                                    'avg_faminc_1mi',
#                                                    'avghhinc_1mi', 'black_1mi',
#                                                    'black_p_1mi', 'boomer_1mi',
#                                                    'boomer_p_1mi',
#                                                    'com0002_p_1mi',
#                                                    'com0205_p_1...
#                                                   OrdinalEncoder(categories=[['Small '
#                                                                               'Town '
#                                                                               '(6)',
#                                                                               'Small '
#                                                                               'City '
#                                                                               '(5)',
#                                                                               'Medium '
#                                                                               'City '
#                                                                               '(4)',
#                                                                               'Large '
#                                                                               'City '
#                                                                               '(3)',
#                                                                               'Large '
#                                                                               'Metro '
#                                                                               '(2)',
#                                                                               'Very '
#                                                                               'Large '
#                                                                               'Metro '
#                                                                               '(1)']],
#                                                                  dtype=<class 'int'>),
#                                                   ['market_size']),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   ['dma_name', 'store_density',
#                                                    'state_name'])])),
#                 ('lgbmclassifier', LGBMClassifier(random_state=42))])

# %%
pipe.score(X_test, y_test)
# Out:
# 0.44375
