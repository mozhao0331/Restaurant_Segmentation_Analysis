# %% [markdown]
# # Draft for Model (Smoothie King) - dependent on feature selection
#
# @TODO: add filtered feature to preprocess step before model comparison
# - Logistic Regression
# - RandomForestClassifier
# - RandomForestClassifier + PCA
# - Hierarchical Clustering
# - Hierarchical Clustering + PCA

# %% [markdown]
# ## Preprocess

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import os
import string
import sys
from collections import deque

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import seaborn as sns
from sklearn import datasets
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.dummy import DummyRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import (
    cross_val_score,
    cross_validate,
    train_test_split,
)
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler
from sklearn.svm import SVR
from sklearn.decomposition import PCA

# %%
sys.path.append("../../src/.")
from preprocess_data import data_transform_pipeline

# %%
DIR = "../../data/"
SMOOTHIE = "Smoothie King/smoothie_king_"

# %%
smoothie_demographic = pd.read_csv(DIR + SMOOTHIE + "demographic_variables.csv")
smoothie_stores = pd.read_csv(DIR + SMOOTHIE + "stores.csv")
smoothie_poi_variables = pd.read_csv(DIR + SMOOTHIE + "poi_variables.csv")
smoothie_sister = pd.read_csv(DIR + SMOOTHIE + "competition_sister_variables.csv")
smoothie_trade_area = pd.read_csv(DIR + SMOOTHIE + "trade_area_variables.csv").rename(columns={"store_num": "store"})

# %%
smoothie_merged = smoothie_stores.merge(
    smoothie_demographic, on="store", how="outer"
).merge(
    smoothie_poi_variables, on="store", how="outer"
).merge(
    smoothie_sister, on="store", how="outer"
).merge(
    smoothie_trade_area, on="store", how="outer"
)

# %%
train_df, test_df = train_test_split(smoothie_merged, test_size=0.1, random_state=42)
X_train = train_df.drop(columns=["category"])
y_train = train_df["category"]
train_index = train_df["store"]
X_test = test_df.drop(columns=["category"])
y_test = test_df["category"]
test_index = test_df["store"]

# %%
drop_features = ["store", "longitude", "latitude", "__store_latitude"]
ordinal_features_oth = [
    "market_size",
    "store_density",
]
ordering_ordinal_oth = [
    ["Very Large Metro (1)", "Large Metro (2)", "Large City (3)", "Medium City (4)", "Small City (5)", "Small Town (6)"],
    ["Rural", "Exurban", "Suburban", "Light Suburban", "Light Urban", "Urban", "Super Urban"],
]
categorical_features = ["cbsa_name", "dma_name", "state_name"]

numeric_features = list(set(smoothie_merged.select_dtypes(include=np.number).columns.tolist()) - {"longitude", "latitude"})

# %%
transformed_train, transformed_test = data_transform_pipeline(
    X_train, 
    X_test, 
    train_index,
    test_index,
    drop_features + categorical_features, 
    ordinal_features_oth, 
    ordering_ordinal_oth, 
    [], 
    numeric_features
)

# %%
transformed_train
# Out:
#          dtpop_retired_disabled_3mi  hh_6pers_10mi  hh_type_female_p_5mi
# store
# SK 1662                   -0.579424      -0.359384             -1.128491  \
# SK 1855                    1.238938       0.840169             -0.654563
# SK 1814                   -0.434547       0.550037             -0.857675
# SK 1174                   -0.086866       0.802056              0.164655
# SK 0973                   -0.056329      -0.392756             -0.805769
# ...                             ...            ...                   ...
# SK 0848                    0.161860       0.287258             -0.027173
# SK 0731                   -0.321257      -0.709148              0.683719
# SK 1554                   -0.343752       0.033051             -0.408572
# SK 1070                   -0.300394      -0.523324              1.719590
# SK 1440                   -0.139432      -0.607939              1.724103
#
#          total_comp_adjacent  hh_5pers_10mi  hh_type_female_nochild_10mi
# store
# SK 1662                  0.0      -0.257819                    -0.600428  \
# SK 1855                  0.0       0.953383                     1.716003
# SK 1814                  0.0       0.534410                    -0.087818
# SK 1174                  0.0       0.664104                     0.012040
# SK 0973                  0.0      -0.278668                    -0.401469
# ...                      ...            ...                          ...
# SK 0848                  0.0       0.366118                     0.476507
# SK 0731                  0.0      -0.770148                    -0.433541
# SK 1554                  0.0       0.244378                    -0.508812
# SK 1070                  0.0      -0.575230                    -0.240076
# SK 1440                  0.0      -0.608219                    -0.350235
#
#          banks_2mi  places_of_worship_10mi  hh_3vehicle_p_2mi
# store
# SK 1662  -0.852148               -0.496453           2.413640  \
# SK 1855  -0.135743                1.219795          -0.815435
# SK 1814  -0.692947                0.069129           1.292340
# SK 1174  -0.613346               -0.058723           0.791238
# SK 0973  -0.135743               -0.596135           0.845168
# ...            ...                     ...                ...
# SK 0848   2.411472                0.498191          -1.210923
# SK 0731   0.262259               -0.596135           0.476644
# SK 1554   0.182659               -0.390271           1.009206
# SK 1070   0.023458               -0.340431           0.332830
# SK 1440  -0.533746               -0.388104          -1.330019
#
#          emp_construction_p_5mi  ...  inrix_breakfast_ew  dtpop_students_1mi
# store                            ...
# SK 1662                1.914418  ...           -0.127435           -0.260262  \
# SK 1855               -0.832126  ...            1.871402           -0.284324
# SK 1814               -0.751213  ...           -0.881252           -0.224830
# SK 1174                3.460754  ...            0.418524            3.531476
# SK 0973               -0.611863  ...            0.591827           -0.327424
# ...                         ...  ...                 ...                 ...
# SK 0848                0.718705  ...           -0.084375           -0.090506
# SK 0731               -0.472513  ...           -0.901985           -0.189663
# SK 1554               -0.162347  ...            1.734780            0.387295
# SK 1070               -1.007438  ...           -0.405465           -0.258411
# SK 1440               -0.850107  ...            1.642280            0.170473
#
#          other_p_ta  hispanic_p_3mi  millenial_ta
# store
# SK 1662    0.261417       -0.493691      1.628835  \
# SK 1855   -0.034546       -0.770779      0.725838
# SK 1814   -0.004950        0.004458     -1.042001
# SK 1174   -0.315711        1.231560      0.183949
# SK 0973   -0.789252       -0.521096      0.105596
# ...             ...             ...           ...
# SK 0848   -0.278716       -0.544846     -1.005663
# SK 0731   -0.559880       -0.789657      0.469656
# SK 1554    0.305811        0.402124      0.017703
# SK 1070   -1.551356       -0.788439     -1.231639
# SK 1440    0.609173       -0.555199     -0.388373
#
#          emp_healthcare_social_assistance_p_ta  hh_1pers_p_ta
# store
# SK 1662                               0.094609      -1.302303  \
# SK 1855                               0.462556       1.035923
# SK 1814                               2.213988      -1.668389
# SK 1174                              -1.134903      -0.907875
# SK 0973                              -0.156728      -1.049586
# ...                                        ...            ...
# SK 0848                               1.122598       2.166065
# SK 0731                              -0.335607       0.473804
# SK 1554                              -0.502033      -1.062576
# SK 1070                               0.802201       0.373425
# SK 1440                               0.819183       0.623781
#
#          spend_lunch_1mi  market_size  store_density
# store
# SK 1662        -0.218520          1.0            0.0
# SK 1855         0.360451          0.0            3.0
# SK 1814        -0.078498          0.0            1.0
# SK 1174         0.262951          0.0            3.0
# SK 0973        -0.185362          0.0            1.0
# ...                  ...          ...            ...
# SK 0848         0.675746          0.0            2.0
# SK 0731        -0.536380          3.0            1.0
# SK 1554         0.165580          0.0            1.0
# SK 1070        -0.278733          2.0            1.0
# SK 1440        -0.149918          3.0            3.0
#
# [716 rows x 1327 columns]

# %% [markdown]
# ## Logistic Regression (One vs Rest)

# %%
class_weight = {
    "HOME": 0.29,
    "OTHER": 0.14,
    "SHOPPING": 0.24,
    "TRAVEL": 0.15,
    "WORK": 0.27
}

# %%
pipe_lr = make_pipeline(
    LogisticRegression(
        penalty="l1", 
        random_state=42, 
        solver="saga", 
        max_iter=2000, 
        multi_class="ovr", 
        class_weight=class_weight,
        n_jobs=-1
    )
)

# %% [markdown]
# ---
# Transformed

# %%
pipe_lr.fit(transformed_train, y_train)
print(pipe_lr.score(transformed_train, y_train))
print(pipe_lr.score(transformed_test, y_test))
# Out:
# 0.6550279329608939
# 0.475

# %% [markdown]
# ---
# Transformed + reduced

# %%
features = [
    'market_size', 
    'com0811_p_ta', 
    'nces_public_schools_nearest_dist',
    'transitstop_nearest_dist',
    'osm_highway_exits_count_2mi',
    'dmm_nearest_dist',
    'dmm_gla_1mi',
    'ipeds_postsecondary_schools_total_enrollment_2mi',
    'hrsa_hospitals_3mi',
    'nces_private_schools_nearest_dist',
    'pop_seasonal_ta',
    'osm_nearest_exit_dist',
    'com0002_p_ta',
    'genz_p_ta',
    'centerxy_gla_effective_5mi',
    'military_installations_5mi',
    'places_of_worship_3mi',
    'hrsa_hospitals_nearest_dist',
    'inrix_ew_distance',
    'age85pl_p_ta',
    'dmm_count_2mi',
    'genx_p_ta',
    'dtpop_students_p_ta',
]

# %%
reduced_train = transformed_train[features]
reduced_test = transformed_test[features]
reduced_train
# Out:
#          market_size  com0811_p_ta  nces_public_schools_nearest_dist
# store
# SK 1662          1.0      0.267111                          1.338132  \
# SK 1855          0.0      0.525438                          0.255703
# SK 1814          0.0     -1.110633                          0.568984
# SK 1174          0.0     -1.275023                         -0.729726
# SK 0973          0.0     -0.498477                          0.072358
# ...              ...           ...                               ...
# SK 0848          0.0      0.210748                         -0.021750
# SK 0731          3.0      0.527003                         -0.525588
# SK 1554          0.0     -1.611631                         -0.068760
# SK 1070          2.0     -0.570495                         -0.506042
# SK 1440          3.0     -1.307901                         -0.317476
#
#          transitstop_nearest_dist  osm_highway_exits_count_2mi
# store
# SK 1662                 -0.346193                    -0.772777  \
# SK 1855                 -0.373329                    -0.772777
# SK 1814                 -0.032137                     0.020070
# SK 1174                 -0.155706                    -0.772777
# SK 0973                 -0.450916                    -0.277248
# ...                           ...                          ...
# SK 0848                 -0.448298                     2.002190
# SK 0731                 -0.451547                    -0.475459
# SK 1554                  0.059641                    -0.079036
# SK 1070                 -0.452651                     0.020070
# SK 1440                 -0.298444                     0.416494
#
#          dmm_nearest_dist  dmm_gla_1mi
# store
# SK 1662          0.572698    -0.741297  \
# SK 1855          0.184308    -0.741297
# SK 1814         -0.479654    -0.288608
# SK 1174          0.367383    -0.741297
# SK 0973         -0.310077    -0.130037
# ...                   ...          ...
# SK 0848         -0.226667    -0.153204
# SK 0731         -0.510320     0.341832
# SK 1554         -0.156793    -0.741297
# SK 1070         -0.496332    -0.187736
# SK 1440         -0.109174    -0.741297
#
#          ipeds_postsecondary_schools_total_enrollment_2mi  hrsa_hospitals_3mi
# store
# SK 1662                                         -0.391589           -0.752078  \
# SK 1855                                         -0.376878           -0.070879
# SK 1814                                         -0.391589           -0.411478
# SK 1174                                          2.564449           -0.752078
# SK 0973                                         -0.391589           -0.752078
# ...                                                   ...                 ...
# SK 0848                                          1.418769            0.610320
# SK 0731                                          0.119614           -0.411478
# SK 1554                                         -0.391589           -0.411478
# SK 1070                                         -0.375534            1.972717
# SK 1440                                          0.653591            0.950919
#
#          nces_private_schools_nearest_dist  ...  genz_p_ta
# store                                       ...
# SK 1662                          -0.484490  ...   0.816515  \
# SK 1855                          -0.753225  ...  -0.848056
# SK 1814                          -0.424224  ...   0.743548
# SK 1174                          -0.159688  ...  -0.145744
# SK 0973                          -0.107871  ...  -0.273437
# ...                                    ...  ...        ...
# SK 0848                          -0.433074  ...  -0.775089
# SK 0731                           0.625096  ...  -0.086458
# SK 1554                          -0.362380  ...   0.586211
# SK 1070                          -0.381624  ...  -0.303080
# SK 1440                          -0.029623  ...  -0.480938
#
#          centerxy_gla_effective_5mi  military_installations_5mi
# store
# SK 1662                   -0.867218                   -0.219922  \
# SK 1855                   -0.080284                   -0.219922
# SK 1814                    0.762966                   -0.219922
# SK 1174                    0.308539                   -0.219922
# SK 0973                   -0.646202                    1.010268
# ...                             ...                         ...
# SK 0848                    0.121555                    1.010268
# SK 0731                   -0.005545                   -0.219922
# SK 1554                    0.465162                   -0.219922
# SK 1070                   -0.164587                   -0.219922
# SK 1440                    0.549681                   -0.219922
#
#          places_of_worship_3mi  hrsa_hospitals_nearest_dist
# store
# SK 1662              -0.518870                     1.538579  \
# SK 1855               0.348790                    -0.890793
# SK 1814              -0.413344                    -1.120461
# SK 1174              -0.260917                     0.439084
# SK 0973              -0.436794                     0.871340
# ...                        ...                          ...
# SK 0848               0.677094                    -0.985037
# SK 0731              -0.225742                    -0.531229
# SK 1554              -0.178841                    -0.410919
# SK 1070              -0.002964                    -0.352415
# SK 1440               0.348790                    -0.959052
#
#          inrix_ew_distance  age85pl_p_ta  dmm_count_2mi  genx_p_ta
# store
# SK 1662           0.189643     -0.879793      -1.061480   1.002332  \
# SK 1855          -0.544881      0.148171      -0.074441   1.045927
# SK 1814           1.900470     -0.798023      -0.567961   0.664466
# SK 1174          -0.316340     -0.611121      -1.061480  -0.112987
# SK 0973           1.179956      0.276667      -0.074441  -0.879542
# ...                    ...           ...            ...        ...
# SK 0848          -0.578225     -0.541032       0.912597   1.823380
# SK 0731           0.685826     -0.622802       1.899636   0.751657
# SK 1554           0.043424     -0.751297       0.419078   1.158549
# SK 1070          -0.085082      0.206578      -0.074441  -0.156583
# SK 1440          -0.844152      0.416844       0.912597  -0.356395
#
#          dtpop_students_p_ta
# store
# SK 1662             0.589739
# SK 1855            -0.755550
# SK 1814             0.139076
# SK 1174             2.698979
# SK 0973            -0.494199
# ...                      ...
# SK 0848             0.802506
# SK 0731            -0.100496
# SK 1554             2.129367
# SK 1070            -0.515978
# SK 1440            -0.078717
#
# [716 rows x 23 columns]

# %%
pipe_lr = make_pipeline(
    LogisticRegression(
        penalty="l1", 
        random_state=42, 
        solver="saga", 
        max_iter=2000, 
        multi_class="ovr", 
        # class_weight=class_weight,
        n_jobs=-1
    )
)

# %%
pipe_lr.fit(reduced_train, y_train)
print(pipe_lr.score(reduced_train, y_train))
print(pipe_lr.score(reduced_test, y_test))
# Out:
# 0.4958100558659218
# 0.4375

# %% [markdown]
# ## PCA

# %%
n_components = 70
pca = PCA(n_components=n_components, whiten=True, random_state=42)
pca.fit(transformed_X)

# %%
df = pd.DataFrame(
    data=np.cumsum(pca.explained_variance_ratio_),
    columns=["cummulative variance_explained (%)"],
    index=range(1, n_components + 1),
)
df.index.name = "n_components"

# %%
plt.figure(figsize=(8, 6))
plt.xticks(range(1, 71, 5))
plt.xlabel("number of components")
plt.ylabel("cumulative explained variance ratio")
plt.plot(range(1, 71), np.cumsum(pca.explained_variance_ratio_))
plt.grid()
plt.show()

# %%
feature_names_out = pca.get_feature_names_out(column_names)
feature_names_out

# %%
transformed_features = pd.DataFrame(abs(pca.components_), columns=column_names, index=feature_names_out)
transformed_features.head()

# %% [markdown]
# ### Try 1: Filter and Count Important Features (of heavy weights)
#
# Filter the values in the PCA component matrix, and count the occurrence of the features in the filtered matrix.

# %%
pca0_df = transformed_features.iloc[0].sort_values(axis=0, ascending=True)
pca0_df.filter(pca0_df > 0.01)

# %%
W = abs(pca.components_)
features = transformed_features.columns
long_results = []
for i in range(W.shape[0]):
    array = W[i]
    heavy_idx = np.where(array > 0.01)
    long_results += list(features[heavy_idx])

# %%
count = pd.Series(long_results).value_counts()
count[:20]

# %% [markdown]
# ## Hierachical Clustering

# %%
from scipy.cluster.hierarchy import (
    average,
    complete,
    dendrogram,
    fcluster,
    single,
    ward,
)

# %%
linkage_array = complete(transformed_X)
hier_labels = fcluster(linkage_array, 5, criterion="maxclust") 
# plot_dendrogram_clusters(X, linkage_array, hier_labels, linkage_type='complete', title="maxclust 3")

# %%
hier_labels

# %% [markdown]
# ## PCA + Hierarchical Clustering

# %%
from scipy.cluster.hierarchy import (
    average,
    complete,
    dendrogram,
    fcluster,
    single,
    ward,
)

X = pca.transform(transformed_X)

# %%
linkage_array = complete(X)
hier_labels = fcluster(linkage_array, 5, criterion="maxclust") 
# plot_dendrogram_clusters(X, linkage_array, hier_labels, linkage_type='complete', title="maxclust 3")

# %%
hier_labels

# %%
y_train

# %% [markdown]
# ## Random Forest Classifier

# %%
rf_pipe = make_pipeline(preprocessor, RandomForestClassifier(max_depth=50))
scores = cross_validate(rf_pipe, X_train, y_train, return_train_score=True)
pd.DataFrame(scores)

# %%
# from sklearn.model_selection import RandomizedSearchCV

# param_grid = {
#     "randomforestclassifier__max_depth": range(5, 30),
# }

# random_search = RandomizedSearchCV(
#     rf_pipe_best, param_distributions=param_grid, n_jobs=-1, n_iter=20, cv=5, random_state=42
# )
# random_search.fit(X_train, y_train)
# pd.DataFrame(random_search.cv_results_)[
#     [
#         "mean_test_score",
#         "param_randomforestclassifier__max_depth",
#         "mean_fit_time",
#         "rank_test_score",
#     ]
# ].set_index("rank_test_score").sort_index().T

# %%
# from random search above, best max depth was 23
rf_pipe_best = make_pipeline(preprocessor, RandomForestClassifier(max_depth=23))
scores = cross_validate(rf_pipe_best, X_train, y_train, return_train_score=True)
pd.DataFrame(scores)

# %%
rf_best_model = rf_pipe_best.named_steps["randomforestclassifier"]

# %%
rf_best_model.fit(transformed_X, y_train)

# %%
importance = rf_best_model.feature_importances_
for i,v in enumerate(importance):
    if v > 0.002:
        print(f'Feature: {column_names[i]}, Score: {v}')
        
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()

# %% [markdown]
# ## PCA + Random Forest Classifier

# %%
from sklearn.decomposition import PCA


pca_rf_pipe = make_pipeline(preprocessor, PCA(n_components=60, whiten=True, random_state=0), RandomForestClassifier(max_depth=20))
scores = cross_validate(pca_rf_pipe, X_train, y_train, return_train_score=True)
pd.DataFrame(scores)

# %%
# from sklearn.model_selection import RandomizedSearchCV

# param_grid = {
#     "pca__n_components": range(10, 60),
#     "randomforestclassifier__max_depth": range(12, 30),
# }

# print("Grid size: %d" % (np.prod(list(map(len, param_grid.values())))))
# param_grid

# %%
# random_search = RandomizedSearchCV(
#     pca_rf_pipe, param_distributions=param_grid, n_jobs=-1, n_iter=20, cv=5, random_state=42
# )
# random_search.fit(X_train, y_train)

# %%
# pd.DataFrame(random_search.cv_results_)[
#     [
#         "mean_test_score",
#         "param_pca__n_components",
#         "param_randomforestclassifier__max_depth",
#         "mean_fit_time",
#         "rank_test_score",
#     ]
# ].set_index("rank_test_score").sort_index().T

# %%
# from above random search, best param is n_components=13 and max_depth=28
pca_rf_best_pipe = make_pipeline(
    preprocessor, 
    PCA(n_components=13, whiten=True, random_state=0), 
    RandomForestClassifier(max_depth=28)
)
pca_rf_best_pipe
